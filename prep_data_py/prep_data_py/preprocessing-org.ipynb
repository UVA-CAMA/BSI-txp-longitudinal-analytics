# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)#pd.reset_option(“max_columns”)
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
sns.set_style('whitegrid')

# %% [markdown]
# # ---- Data Preparation ----
# ## 1. load raw data
# (note: all datasets are saved in same directory '../data/...csv')

# %%
uva = pd.read_csv('../data/uva_merged.csv', low_memory=False)
print("shape: ", uva.shape)
# Out:
# shape:  (5124891, 141)

# %%
for i, x in enumerate(uva.columns):
    print(i,x)
# Out:
# 0 bid
# 1 hr
# 2 rr
# 3 so2
# 4 x.hr.rr
# 5 x.hr.so2
# 6 x.rr.so2
# 7 s.rr
# 8 s.so2
# 9 rsa
# 10 edrk
# 11 edr
# 12 x.hr.edr
# 13 mrr
# 14 srr
# 15 af
# 16 cosen
# 17 dfa
# 18 ds
# 19 lds
# 20 hem.s.1
# 21 hem.s
# 22 hem.m
# 23 int.s.amani
# 24 int.s
# 25 int.m
# 26 sep.s
# 27 sep.m
# 28 s.edrk
# 29 n.edrk
# 30 s.edr
# 31 pt.rr
# 32 s.pt.rr
# 33 s.hr
# 34 pdel
# 35 s.pdel
# 36 x.ptt.ptt
# 37 x.rri.ptt
# 38 te.rri.ptt
# 39 SODIUM
# 40 POTASSIUM
# 41 CHLORIDE
# 42 CO2
# 43 BLOOD.UREA.NITROGEN
# 44 CREATININE
# 45 GLUCOSE
# 46 CALCIUM
# 47 WHITE.BLOOD.CELL.COUNT
# 48 HEMOGLOBIN
# 49 HEMATOCRIT
# 50 PLATELET.COUNT
# 51 NEUTROPHILS.PERCENT
# 52 AST.GOT
# 53 ALT.GPT
# 54 TOTAL.PROTEIN
# 55 ALBUMIN
# 56 TOTAL.BILIRUBIN
# 57 ALKALINE.PHOSPHATASE
# 58 MAGNESIUM
# 59 PHOSPHORUS
# 60 OXYGEN.SATURATION
# 61 PARTIAL.THROMBOPLASTIN.TIME
# 62 PROTIME
# 63 PROTIME.INR
# 64 PH.ARTERIAL
# 65 PCO2
# 66 PO2
# 67 BICARBONATE
# 68 BASE.EXCESS
# 69 FIO2
# 70 TROPONIN.I
# 71 LACTIC.ACID
# 72 havelabs
# 73 haveabg
# 74 Resp
# 75 SpO2
# 76 Pulse
# 77 SBP
# 78 O2.Flow
# 79 Temp
# 80 GCS
# 81 PEEP
# 82 FiO2
# 83 Voided.Urine
# 84 DBP
# 85 age
# 86 unit
# 87 bps
# 88 bpd
# 89 pt.used
# 90 crm
# 91 SIRS
# 92 CCI
# 93 MI
# 94 CHF
# 95 PVD
# 96 CVD
# 97 DEM
# 98 CPD
# 99 RHM
# 100 MLD
# 101 DNC
# 102 DWC
# 103 REN
# 104 CAN
# 105 LIV
# 106 MET
# 107 HIV
# 108 APACHE
# 109 nline
# 110 tt.line
# 111 tsa
# 112 id
# 113 instance_id
# 114 sets_per_instance
# 115 growths_per_instance
# 116 pathogens_per_instance
# 117 possible_contaminants_per_instance
# 118 confirmed_contaminants_per_instance
# 119 set_results
# 120 Instance_Verdict
# 121 GP_isolate_n
# 122 GN_isolate_n
# 123 fungus_isolate_n
# 124 mycobacteria_isolate_n
# 125 all_isolate_n
# 126 GP
# 127 GN
# 128 fungus
# 129 mycobacteria
# 130 polymicrobial
# 131 Transplant Status
# 132 Confirmed Txp
# 133 SOT
# 134 HSCT
# 135 Transplant AdmissionDiff
# 136 tsa_bc
# 137 ID
# 138 tsa_bc_15
# 139 True_positive_n
# 140 True_positive

# %% [markdown]
# ## 2. select columns
# notation: _uva - raw column names

# %%
# select feature name respectively
info_uva = ['id', 'tsa']

demo_uva = ['age']

vital_uva = ['Temp',
             'Resp',
             'Pulse',
             'hr',
             'SBP',
             'DBP',
             'SpO2',
             'GCS',
             'FiO2',
             'O2.Flow'
             ]

lab_uva = ['GLUCOSE',
           'TOTAL.BILIRUBIN',
           'POTASSIUM',
           'ALBUMIN',
           'CALCIUM',
           'SODIUM',
           'WHITE.BLOOD.CELL.COUNT',
           'PHOSPHORUS',
           'PROTIME.INR',
           'CREATININE',
           'PLATELET.COUNT',
           'ALT.GPT',
           'CO2',
           'ALKALINE.PHOSPHATASE',
           'AST.GOT',
           'PCO2',
           'CHLORIDE',
           'TROPONIN.I',
           'PARTIAL.THROMBOPLASTIN.TIME',
           'LACTIC.ACID',
           'BLOOD.UREA.NITROGEN',
           'OXYGEN.SATURATION',
           'MAGNESIUM',
           'FIO2' ,
           's.rr', # sd of respiratory rate by chest impedance (breaths/min)
           's.edr', # sd of electrocardiogram-derived respiratory rate (breaths/min)
           'srr', # sd of the R-R interval by cardiac telemetry (s)
           's.hr', # sd of heart rate by cardiac telemetry (beats/min)
           'ds', # local dynamics density of heart rate
           'mrr', # mean R-R interval by cardiac telemetry (s)
           's.so2', # sd of oxygen saturation by pulse oximetry (%)
           'x.hr.edr',
           'x.hr.so2'
          ]


uva_X = info_uva + demo_uva + vital_uva + lab_uva
uva_y = ['GP','GN','fungus','mycobacteria','Confirmed Txp','True_positive']
df_org = uva.loc[:, uva_X + uva_y].copy()

# %% [markdown]
# ## 3. rename columns

# %%
# make sure all '.' are replaced by '_'
df_org.columns = df_org.columns.str.replace(r".", "_")

# %% [markdown]
# # 4. fix outliers in data

# %%
df = df_org

# fix labs
df.loc[df['GLUCOSE']<49,['GLUCOSE']]=49
df.loc[df['GLUCOSE']>460,['GLUCOSE']]=460
df.loc[df['TOTAL_BILIRUBIN']>50,['TOTAL_BILIRUBIN']]=50
df.loc[df['POTASSIUM']>6.6,['POTASSIUM']]=6.6
df.loc[df['POTASSIUM']<2.4,['POTASSIUM']]=2.4
df.loc[df['ALBUMIN']>5,['ALBUMIN']]=5
df.loc[df['CALCIUM']>12,['CALCIUM']]=12
df.loc[df['CALCIUM']<6.1,['CALCIUM']]=6.1
df.loc[df['SODIUM']<119,['SODIUM']]=119
df.loc[df['SODIUM']>172,['SODIUM']]=172
df.loc[df['WHITE_BLOOD_CELL_COUNT']>33.85,['WHITE_BLOOD_CELL_COUNT']]=33.85
df.loc[df['PHOSPHORUS']>8,['PHOSPHORUS']]=8
df.loc[df['PROTIME_INR']>5,['PROTIME_INR']]=5
df.loc[df['CREATININE']>10,['CREATININE']]=10
df.loc[df['PLATELET_COUNT']>1001,['PLATELET_COUNT']]=1001
df.loc[df['ALT_GPT']>1085,['ALT_GPT']]=1085
df.loc[df['CO2']>40,['CO2']]=40
df.loc[df['ALKALINE_PHOSPHATASE']>800,['ALKALINE_PHOSPHATASE']]=800
df.loc[df['AST_GOT']>1203,['AST_GOT']]=1203
df.loc[df['PCO2']>100.5,['PCO2']]=100.5
df.loc[df['CHLORIDE']>132,['CHLORIDE']]=132
df.loc[df['CHLORIDE']<83,['CHLORIDE']]=83
df.loc[df['TROPONIN_I']>23.5,['TROPONIN_I']]=23.5
df.loc[df['PARTIAL_THROMBOPLASTIN_TIME']>140,['PARTIAL_THROMBOPLASTIN_TIME']]=140
df.loc[df['LACTIC_ACID']>19.1,['LACTIC_ACID']]=19.1
df.loc[df['BLOOD_UREA_NITROGEN']>143,['BLOOD_UREA_NITROGEN']]=143
df.loc[df['OXYGEN_SATURATION']<17.6,['OXYGEN_SATURATION']]=17.6
df.loc[df['MAGNESIUM']>3.4,['MAGNESIUM']]=3.4
df.loc[(df['FIO2']<21)|(df['FIO2'].isna()),['FIO2']]=21


# fix vitals
## temperature F to C
df.loc[df['Temp']>104, ['Temp']]=104
df.loc[df['Temp'].between(80,92), ['Temp']]=92
df.loc[df['Temp'].between(92,104),['Temp']] = df[df['Temp'].between(92,104)]['Temp'].apply(lambda x: (x-32)*5/9)
df.loc[df['Temp']<33.33333, ['Temp']]=33.33333
df.loc[df['Temp'].between(40,80), ['Temp']]=40
df.loc[df['Resp']>80,['Resp']]=80
df.loc[df['Resp']<5,['Resp']]=5
df.loc[df['Pulse']>300,['Pulse']]=300
df.loc[df['Pulse']<30,['Pulse']]=30
# heartrate
df.loc[df['hr']>300,['hr']]=300
df.loc[df['hr']<30,['hr']]=30
df.loc[df['SBP']>250,['SBP']]=250
df.loc[df['SBP']<40,['SBP']]=40
df.loc[df['DBP']>150,['DBP']]=150
df.loc[df['DBP']<26,['DBP']]=26
df.loc[df['SpO2']<79,['SpO2']]=79
#df.loc[df['GCS']<10,['GCS']]=10
df.loc[(df['FiO2']<21)|(df['FiO2'].isna()),['FiO2']]=21
df.loc[(df['O2_Flow']<0)|(df['O2_Flow'].isna()),['O2_Flow']]=0

df_fixed = df.copy()

# %% [markdown]
# # ---- Episode sequences ----
# ## 1. individual data imputation
# Vital signs are kept for 24 hours. Labs are kept for 48 hours

# %%
def data_imputation(df):
    """
    data imputation on clinical features
    
    Inputs:
    df -- dataframe of ONE patient
    
    Outputs:
    df -- patient dataframe after imputation
    
    """
   
    info = ['id', 'tsa']

    demo = ['age']

    vital = ['Temp', 'Resp', 'Pulse','hr', 'SBP', 'DBP', 'SpO2','GCS', 'FiO2', 'O2_Flow']

    lab = ['GLUCOSE', 'TOTAL_BILIRUBIN', 'POTASSIUM',
           'ALBUMIN', 'CALCIUM', 'SODIUM', 'WHITE_BLOOD_CELL_COUNT', 'PHOSPHORUS',
           'PROTIME_INR', 'CREATININE', 'PLATELET_COUNT', 'ALT_GPT', 'CO2',
           'ALKALINE_PHOSPHATASE', 'AST_GOT', 'PCO2', 'CHLORIDE', 'TROPONIN_I',
           'PARTIAL_THROMBOPLASTIN_TIME', 'LACTIC_ACID', 'BLOOD_UREA_NITROGEN',
           'OXYGEN_SATURATION', 'MAGNESIUM', 'FIO2', 's_rr', 's_edr', 'srr',
           's_hr', 'ds', 'mrr', 's_so2', 'x_hr_edr','x_hr_so2']

    interpolation_cols = []
    median_cols = []
    
    
    try:
        df[vital] = df[vital].fillna(method='ffill',limit=24*4) 
        df[lab] = df[lab].fillna(method='ffill',limit=48*4) 
        df[interpolation_cols] = df[interpolation_cols].interpolate(limit_direction='both')
        df[median_cols] = df[median_cols].fillna(df[median_cols].median())   
        for col in demo:
            df[col] = df.loc[df[col].first_valid_index(), col]
    except:
        pass
    return df

# %% [markdown]
# ## 2. save episode sequences into 2D dataframe
# - ep: episode
# - B: before
# - A: after
# - imp: imputation
# - org: original (no imputation)

# %%
def preprocess(df, patient_id, h_before=12, h_after=24, unit=15, imputation=True, test=False, each=False):
    
    """
    
    Inputs:
    df -- the original dataframe
    patient_id -- id of one patient in target group
    h_before -- how many hours BEFORE a positive/negative instance(default 12h)
    h_after -- how many hours AFTER a positive/negative instance(default 24h)
    unit -- how many minutes in a time unit(default 15mins)
    imputation -- whether or not fulfilling the gaps(default True)
    test -- whether or not testing function(default False)
    each_pos -- whether or not slice episode around each positive/negative instance(default False)
    
    Outputs:
    patient -- pre-processed dataframe for this patient
    
    """
    import missingno as msno
    
    # Subset single patient dataframe from original dataframe
    patient = df[df['id'] == patient_id]
    patient = patient.reset_index(drop=True)
    
    # Make patient dataframe one time unit per row
    ts = pd.DataFrame(range(int(patient['tsa'].iloc[0]),int(patient['tsa'].iloc[-1]),unit),columns=['ts'])
    patient = pd.merge(left=ts,right=patient,left_on='ts',right_on='tsa',how='left',copy = False)
    
    # Data imputation
    if test: msno.matrix(patient);       
    if imputation: patient = data_imputation(patient)
    if test: msno.matrix(patient);   
    
    # Slice episodes
    B = h_before*60/unit # #of time units before each positive instance
    A = h_after*60/unit # #of time units after each positive instance    
    
    ## for positive patients
    pos_idx = patient[patient['True_positive']==1].index.tolist() # positive indices
    neg_idx = patient[patient['True_positive']==0].index.tolist() # negative indices
    
    if test: 
        print(patient_id, "positive index:", pos_idx)
        print(patient_id, "negative index:", neg_idx)
    
    # positive patient    
    if len(pos_idx) > 0: 
        t_ep_list = [] 
        if each:# if we want to slice around every positive instance
            t_ep_list = pos_idx
        else: # only keep time indices at least max(A,B) units later than the last one
            t_ep = pos_idx[0] 
            t_ep_list.append(t_ep)
            for t in pos_idx:
                if t - t_ep > max(A,B):
                    t_ep = t
                    t_ep_list.append(t_ep)       
        
        episodes = pd.DataFrame()
        EP = 0        
        for t in t_ep_list:            
            EP += 1
            episode = patient.iloc[range(max(int(t-B), patient.index[0]),min(int(t+A), patient.index[-1])+1),:]
            episode_idx = list(range(int(t-B),int(t+A+1)))
            episode = episode.reindex(episode_idx, fill_value = np.nan)
            episode = episode.reset_index(drop=True)            
            ## 1. imputation on clinical features (or not)
            #if imputation: episode = data_imputation(episode)
            # 2. fulfill empty cells in patient id
            episode['id'] = patient_id
            # 3. save order of episode for this patient  
            episode['episode'] = EP
            # 4. save relative time within this episode/window:
            episode['relative_time'] = list(range(int(-B),int(A)+1))
            # 5. save BSI 
            episode['BSI'] = 1
            # 6. save infection type all 0 if given
            try:
                infection_list = ['GP','GN','fungus','mycobacteria']
                episode.loc[:,infection_list] = episode.loc[B, infection_list].values.astype(int) 
            except:
                pass
            episodes = pd.concat([episodes, episode])  # append to cases dataframe
            assert(episodes.shape[0]%(B+A+1)==0), "Error in patient"+str(patient_id)# if number of rows is not multiple of S+E+1, raise error
            
            
    # negative patient
    elif len(neg_idx) > 0: # using elif (not if) because we only consider all-time negative patients       
        assert(len(pos_idx) == 0)
        t_ep_list = [] 
        if each:# if we want to slice around every positive instance
            t_ep_list = neg_idx
        else: # only keep time indices at least max(A,B) units later than the last one
            t_ep = neg_idx[0] 
            t_ep_list.append(t_ep)
            for t in neg_idx:
                if t - t_ep > max(A,B):
                    t_ep = t
                    t_ep_list.append(t_ep)       
        
        episodes = pd.DataFrame()
        EP = 0        
        for t in t_ep_list:  
            EP += 1
            episode = patient.iloc[range(max(int(t-B), patient.index[0]),min(int(t+A), patient.index[-1])+1),:]
            episode_idx = list(range(int(t-B),int(t+A+1)))
            episode = episode.reindex(episode_idx, fill_value = np.nan)
            episode = episode.reset_index(drop=True)            
            ## 1. imputation on clinical features (or not)
            #if imputation: episode = data_imputation(episode)
            # 2. fulfill empty cells in patient id
            episode['id'] = patient_id
            # 3. save order of episode for this patient 
            episode['episode'] = EP
             # 4. save relative time within this episode/window:
            episode['relative_time'] = list(range(int(-B),int(A)+1))
            # 5. save BSI 
            episode['BSI'] = 0
            # 6. save infection type all 0 if given
            try:
                infection_list = ['GP','GN','fungus','mycobacteria']
                episode.loc[:,infection_list] = 0
            except:
                pass
            episodes = pd.concat([episodes, episode])  # append to cases dataframe
            assert(episodes.shape[0]%(B+A+1)==0), "Error in patient"+str(patient_id)# if number of rows is not multiple of S+E+1, raise error
           
        
    try:# Save transplant statues of this patient if given
        episodes['txp'] = 1 if 'yes' in patient['Confirmed Txp'].unique().tolist() else 0 # save transplant status
    except: 
        pass
    
    if test: msno.matrix(episodes);
    
    return episodes

# %% [markdown]
# #### testing case test # 7805

# %%
case = preprocess(df, 7805, h_before=1*24+4, h_after=2*24-4, test=True, imputation=True)
# Out:
# 7805 positive index: [0, 153, 218, 314, 410, 602, 698, 794, 890, 986, 1082, 1178, 1274, 1366, 1462, 1558, 1654, 1750, 1846, 2518, 3439, 3505, 3670, 3695, 3705, 3730, 3766, 3800, 3883, 3958, 4236, 4293, 4367]
# 7805 negative index: [506, 1965, 2074, 2326, 2614]

# %% [markdown]
# ####  episode sequence

# %%
bco_id = list(set(uva['ID'].dropna().astype(int)))
ep = pd.DataFrame()
for patient_id in bco_id[50:80]:
    patient_seq = preprocess(df, patient_id, h_before=1*24-5, h_after=2*24+5, imputation=True)
    ep = pd.concat([ep, patient_seq])
#ep['relative_time']= ep['relative_time']-5*4
#ep.to_csv('../data/ep_uva_1B2A.csv', index = False)

# %% [markdown]
# ## 3. save safe_zone window for control group

# %%
def slice_safe_zone(df,feas, patient_id, h_before=7*24-5, h_after=7*24+5, unit=15, ep_len=48, imputation=True):

    info = ['id','tsa','Confirmed Txp','True_positive']
    
    patient = df[df['id'] == patient_id][info+feas]
    patient = patient.reset_index(drop=True)

    # Make patient dataframe one time unit per row
    ts = pd.DataFrame(range(int(patient['tsa'].iloc[0]),int(patient['tsa'].iloc[-1]),unit),columns=['ts'])
    patient = pd.merge(left=ts,right=patient,left_on='ts',right_on='tsa',how='left',copy = False)
    
    # patient-wise data imputation
    if imputation: patient = data_imputation(patient)
    
    # create a column for danger zone (infection episode) tag, set defualt value 0
    patient['tag'] = 0
    # get blood culture instance index
    ins_idx = patient[patient['True_positive'].isin([0,1])].index.tolist()
    # set tag of rows within danger zone as 1
    for t in ins_idx:
        patient.loc[range(max(int(t-B), patient.index[0]),min(int(t+A), patient.index[-1])+1),['tag']] = 1

    # get all safe zone data 
    safe_zone = pd.DataFrame()
    safe_zone = patient[patient['tag']==0].copy()
    

    # create empty result dataframe
    safe_window = pd.DataFrame()
    try:
        idx = safe_zone[feas].count(axis=1).idxmax() # get index of the first row who contains most observations 
        #print("idxmax",idx)
        safe_window = safe_zone.loc[range(idx,min(int(idx+ep_len*60/unit+1), safe_zone.index[-1]+1)),:].copy()
        # 1. coerce safe_window to be episode-length
        safe_window = safe_window.reset_index(drop=True)
        safe_window = safe_window.reindex(list(range(0, int(ep_len*60/unit+1))))
        # 2. keep txp status
        safe_window['txp'] = 1 if 'yes' in patient['Confirmed Txp'].unique().tolist() else 0 # save transplant status
        assert(safe_window['txp'].notnull().all())
        # 3. save patient id
        safe_window['id'] = patient_id
        assert(safe_window['id'].notnull().all())
        # 4. fulfill empty cells with personal safe_zone median
        safe_window[feas] = safe_window[feas].fillna(safe_zone[feas].median())
        # 5. save mean and max baseline_df of feas for this patient 
        
        for f in feas:
            safe_window[f+'_mean'] = safe_zone[f].mean()
            safe_window[f+'_max'] = safe_zone[f].max()
        
        #print(safe_window)
        print ("get safe window from patient", patient_id)
    except: 
        pass
    return safe_window

# %%
feas = ['Temp','Resp','WHITE_BLOOD_CELL_COUNT','Pulse']
bco_id = list(set(uva['ID'].dropna().astype(int)))
safe_df = pd.DataFrame()
for patient_id in bco_id:
    safe_zone = slice_safe_zone(df_fixed,feas,patient_id)
    safe_df = pd.concat([safe_df, safe_zone])
safe_df.to_csv('../data/safe48_uva.csv', index = False)
# Out:
# get safe window from patient 10
# get safe window from patient 14
# get safe window from patient 17
# get safe window from patient 22
# get safe window from patient 23
# get safe window from patient 26
# get safe window from patient 31
# get safe window from patient 40
# get safe window from patient 43
# get safe window from patient 44
# get safe window from patient 46
# get safe window from patient 49
# get safe window from patient 55
# get safe window from patient 59
# get safe window from patient 62
# get safe window from patient 67
# get safe window from patient 68
# get safe window from patient 69
# get safe window from patient 70
# get safe window from patient 72
# get safe window from patient 73
# get safe window from patient 76
# get safe window from patient 77
# get safe window from patient 79
# get safe window from patient 81
# get safe window from patient 83
# get safe window from patient 86
# get safe window from patient 87
# get safe window from patient 88
# get safe window from patient 90
# get safe window from patient 97
# get safe window from patient 99
# get safe window from patient 103
# get safe window from patient 104
# get safe window from patient 105
# get safe window from patient 106
# get safe window from patient 119
# get safe window from patient 122
# get safe window from patient 129
# get safe window from patient 132
# get safe window from patient 2771
# get safe window from patient 2772
# get safe window from patient 2773
# get safe window from patient 2774
# get safe window from patient 2780
# get safe window from patient 2784
# get safe window from patient 2795
# get safe window from patient 2801
# get safe window from patient 2804
# get safe window from patient 2810
# get safe window from patient 2814
# get safe window from patient 2824
# get safe window from patient 2828
# get safe window from patient 2831
# get safe window from patient 2835
# get safe window from patient 2836
# get safe window from patient 2837
# get safe window from patient 2838
# get safe window from patient 2840
# get safe window from patient 2841
# get safe window from patient 2843
# get safe window from patient 2855
# get safe window from patient 2857
# get safe window from patient 2859
# get safe window from patient 2867
# get safe window from patient 2871
# get safe window from patient 2872
# get safe window from patient 2873
# get safe window from patient 2875
# get safe window from patient 2878
# get safe window from patient 2879
# get safe window from patient 2882
# get safe window from patient 2886
# get safe window from patient 2887
# get safe window from patient 2889
# get safe window from patient 2891
# get safe window from patient 2900
# get safe window from patient 2901
# get safe window from patient 2902
# get safe window from patient 2908
# get safe window from patient 2910
# get safe window from patient 2912
# get safe window from patient 2918
# get safe window from patient 2919
# get safe window from patient 2930
# get safe window from patient 2931
# get safe window from patient 2932
# get safe window from patient 2933
# get safe window from patient 2934
# get safe window from patient 2939
# get safe window from patient 2941
# get safe window from patient 2942
# get safe window from patient 2944
# get safe window from patient 2945
# get safe window from patient 2946
# get safe window from patient 2948
# get safe window from patient 2952
# get safe window from patient 2955
# get safe window from patient 2960
# get safe window from patient 2966
# get safe window from patient 2967
# get safe window from patient 2970
# get safe window from patient 2972
# get safe window from patient 2975
# get safe window from patient 2978
# get safe window from patient 2983
# get safe window from patient 2995
# get safe window from patient 2996
# get safe window from patient 2999
# get safe window from patient 3005
# get safe window from patient 3006
# get safe window from patient 3008
# get safe window from patient 3011
# get safe window from patient 3013
# get safe window from patient 3020
# get safe window from patient 3021
# get safe window from patient 3024
# get safe window from patient 3025
# get safe window from patient 3027
# get safe window from patient 3031
# get safe window from patient 3032
# get safe window from patient 3033
# get safe window from patient 3036
# get safe window from patient 3037
# get safe window from patient 3039
# get safe window from patient 3044
# get safe window from patient 3048
# get safe window from patient 3053
# get safe window from patient 3055
# get safe window from patient 3061
# get safe window from patient 3064
# get safe window from patient 3066
# get safe window from patient 3069
# get safe window from patient 3074
# get safe window from patient 3075
# get safe window from patient 3076
# get safe window from patient 3077
# get safe window from patient 3078
# get safe window from patient 3080
# get safe window from patient 3081
# get safe window from patient 3083
# get safe window from patient 3085
# get safe window from patient 3087
# get safe window from patient 3106
# get safe window from patient 3107
# get safe window from patient 3111
# get safe window from patient 3114
# get safe window from patient 3120
# get safe window from patient 3131
# get safe window from patient 3132
# get safe window from patient 3136
# get safe window from patient 3138
# get safe window from patient 3141
# get safe window from patient 3155
# get safe window from patient 3156
# get safe window from patient 3158
# get safe window from patient 3162
# get safe window from patient 3166
# get safe window from patient 3178
# get safe window from patient 3182
# get safe window from patient 3187
# get safe window from patient 3191
# get safe window from patient 3195
# get safe window from patient 3196
# get safe window from patient 3204
# get safe window from patient 3205
# get safe window from patient 3206
# get safe window from patient 3208
# get safe window from patient 3216
# get safe window from patient 3217
# get safe window from patient 3229
# get safe window from patient 3235
# get safe window from patient 3237
# get safe window from patient 3239
# get safe window from patient 3241
# get safe window from patient 3242
# get safe window from patient 3246
# get safe window from patient 3247
# get safe window from patient 3250
# get safe window from patient 3251
# get safe window from patient 3252
# get safe window from patient 3260
# get safe window from patient 3265
# get safe window from patient 3266
# get safe window from patient 3270
# get safe window from patient 3271
# get safe window from patient 3273
# get safe window from patient 3284
# get safe window from patient 3285
# get safe window from patient 3286
# get safe window from patient 3287
# get safe window from patient 3289
# get safe window from patient 3293
# get safe window from patient 3294
# get safe window from patient 3301
# get safe window from patient 3303
# get safe window from patient 3308
# get safe window from patient 3314
# get safe window from patient 3316
# get safe window from patient 3322
# get safe window from patient 3323
# get safe window from patient 3333
# get safe window from patient 3339
# get safe window from patient 3350
# get safe window from patient 3351
# get safe window from patient 3355
# get safe window from patient 3358
# get safe window from patient 3363
# get safe window from patient 3370
# get safe window from patient 3372
# get safe window from patient 3374
# get safe window from patient 3377
# get safe window from patient 3379
# get safe window from patient 3381
# get safe window from patient 3392
# get safe window from patient 3395
# get safe window from patient 3400
# get safe window from patient 3401
# get safe window from patient 3404
# get safe window from patient 3405
# get safe window from patient 3410
# get safe window from patient 3413
# get safe window from patient 3417
# get safe window from patient 3421
# get safe window from patient 3422
# get safe window from patient 3424
# get safe window from patient 3426
# get safe window from patient 3430
# get safe window from patient 3433
# get safe window from patient 3436
# get safe window from patient 3438
# get safe window from patient 3440
# get safe window from patient 3443
# get safe window from patient 3444
# get safe window from patient 3454
# get safe window from patient 3455
# get safe window from patient 3456
# get safe window from patient 3473
# get safe window from patient 3475
# get safe window from patient 3476
# get safe window from patient 3479
# get safe window from patient 3485
# get safe window from patient 3487
# get safe window from patient 3503
# get safe window from patient 3507
# get safe window from patient 3511
# get safe window from patient 3512
# get safe window from patient 3513
# get safe window from patient 3514
# get safe window from patient 3515
# get safe window from patient 3521
# get safe window from patient 3522
# get safe window from patient 3525
# get safe window from patient 3532
# get safe window from patient 3536
# get safe window from patient 3541
# get safe window from patient 3552
# get safe window from patient 3559
# get safe window from patient 3560
# get safe window from patient 3566
# get safe window from patient 3568
# get safe window from patient 3572
# get safe window from patient 3576
# get safe window from patient 3578
# get safe window from patient 3582
# get safe window from patient 3589
# get safe window from patient 3590
# get safe window from patient 3597
# get safe window from patient 3598
# get safe window from patient 3603
# get safe window from patient 3607
# get safe window from patient 3608
# get safe window from patient 3610
# get safe window from patient 3612
# get safe window from patient 3613
# get safe window from patient 3615
# get safe window from patient 3621
# get safe window from patient 3629
# get safe window from patient 3632
# get safe window from patient 3633
# get safe window from patient 3634
# get safe window from patient 3642
# get safe window from patient 3643
# get safe window from patient 3647
# get safe window from patient 3649
# get safe window from patient 3650
# get safe window from patient 3651
# get safe window from patient 3652
# get safe window from patient 3658
# get safe window from patient 3665
# get safe window from patient 3666
# get safe window from patient 3667
# get safe window from patient 3671
# get safe window from patient 3675
# get safe window from patient 3683
# get safe window from patient 3685
# get safe window from patient 3695
# get safe window from patient 3698
# get safe window from patient 3701
# get safe window from patient 3703
# get safe window from patient 3707
# get safe window from patient 3710
# get safe window from patient 3711
# get safe window from patient 3713
# get safe window from patient 3718
# get safe window from patient 3720
# get safe window from patient 3727
# get safe window from patient 3736
# get safe window from patient 3737
# get safe window from patient 3741
# get safe window from patient 3744
# get safe window from patient 3745
# get safe window from patient 3750
# get safe window from patient 3752
# get safe window from patient 3754
# get safe window from patient 3758
# get safe window from patient 3760
# get safe window from patient 3766
# get safe window from patient 3774
# get safe window from patient 3777
# get safe window from patient 3783
# get safe window from patient 3790
# get safe window from patient 3792
# get safe window from patient 3793
# get safe window from patient 3794
# get safe window from patient 3796
# get safe window from patient 3802
# get safe window from patient 3805
# get safe window from patient 3806
# get safe window from patient 3813
# get safe window from patient 3814
# get safe window from patient 3815
# get safe window from patient 3816
# get safe window from patient 3822
# get safe window from patient 3823
# get safe window from patient 3829
# get safe window from patient 3832
# get safe window from patient 3833
# get safe window from patient 3836
# get safe window from patient 3838
# get safe window from patient 3840
# get safe window from patient 3847
# get safe window from patient 3848
# get safe window from patient 3855
# get safe window from patient 3858
# get safe window from patient 3868
# get safe window from patient 3874
# get safe window from patient 3877
# get safe window from patient 3882
# get safe window from patient 3884
# get safe window from patient 3888
# get safe window from patient 3889
# get safe window from patient 3890
# get safe window from patient 3895
# get safe window from patient 3898
# get safe window from patient 3899
# get safe window from patient 3906
# get safe window from patient 3908
# get safe window from patient 3910
# get safe window from patient 3917
# get safe window from patient 3919
# get safe window from patient 3920
# get safe window from patient 3926
# get safe window from patient 3927
# get safe window from patient 3929
# get safe window from patient 3932
# get safe window from patient 3942
# get safe window from patient 3943
# get safe window from patient 3953
# get safe window from patient 3957
# get safe window from patient 3960
# get safe window from patient 3968
# get safe window from patient 3969
# get safe window from patient 3971
# get safe window from patient 3982
# get safe window from patient 3987
# get safe window from patient 3991
# get safe window from patient 3996
# get safe window from patient 3999
# get safe window from patient 4002
# get safe window from patient 4003
# get safe window from patient 4008
# get safe window from patient 4011
# get safe window from patient 4013
# get safe window from patient 4019
# get safe window from patient 4021
# get safe window from patient 4023
# get safe window from patient 4032
# get safe window from patient 4049
# get safe window from patient 4050
# get safe window from patient 4060
# get safe window from patient 4064
# get safe window from patient 4065
# get safe window from patient 4066
# get safe window from patient 4072
# get safe window from patient 4078
# get safe window from patient 4080
# get safe window from patient 4081
# get safe window from patient 4082
# get safe window from patient 4088
# get safe window from patient 4094
# get safe window from patient 4097
# get safe window from patient 4099
# get safe window from patient 4105
# get safe window from patient 4106
# get safe window from patient 4110
# get safe window from patient 4112
# get safe window from patient 4117
# get safe window from patient 4120
# get safe window from patient 4134
# get safe window from patient 4136
# get safe window from patient 4139
# get safe window from patient 4140
# get safe window from patient 4151
# get safe window from patient 4157
# get safe window from patient 4159
# get safe window from patient 4162
# get safe window from patient 4165
# get safe window from patient 4167
# get safe window from patient 4168
# get safe window from patient 4175
# get safe window from patient 4177
# get safe window from patient 4182
# get safe window from patient 4184
# get safe window from patient 4187
# get safe window from patient 4189
# get safe window from patient 4192
# get safe window from patient 4195
# get safe window from patient 4197
# get safe window from patient 4198
# get safe window from patient 4200
# get safe window from patient 4204
# get safe window from patient 4209
# get safe window from patient 4214
# get safe window from patient 4217
# get safe window from patient 4237
# get safe window from patient 4243
# get safe window from patient 4251
# get safe window from patient 4255
# get safe window from patient 4259
# get safe window from patient 4261
# get safe window from patient 4265
# get safe window from patient 4271
# get safe window from patient 4278
# get safe window from patient 4285
# get safe window from patient 4286
# get safe window from patient 4288
# get safe window from patient 4291
# get safe window from patient 4295
# get safe window from patient 4296
# get safe window from patient 4298
# get safe window from patient 4303
# get safe window from patient 4312
# get safe window from patient 4316
# get safe window from patient 4323
# get safe window from patient 4324
# get safe window from patient 4331
# get safe window from patient 4333
# get safe window from patient 4339
# get safe window from patient 4347
# get safe window from patient 4351
# get safe window from patient 4352
# get safe window from patient 4354
# get safe window from patient 4358
# get safe window from patient 4359
# get safe window from patient 4360
# get safe window from patient 4364
# get safe window from patient 4370
# get safe window from patient 4372
# get safe window from patient 4378
# get safe window from patient 4380
# get safe window from patient 4381
# get safe window from patient 4383
# get safe window from patient 4388
# get safe window from patient 4395
# get safe window from patient 4409
# get safe window from patient 4410
# get safe window from patient 4411
# get safe window from patient 4424
# get safe window from patient 4431
# get safe window from patient 4434
# get safe window from patient 4435
# get safe window from patient 4441
# get safe window from patient 4446
# get safe window from patient 4450
# get safe window from patient 4452
# get safe window from patient 4459
# get safe window from patient 4461
# get safe window from patient 4465
# get safe window from patient 4466
# get safe window from patient 4474
# get safe window from patient 4481
# get safe window from patient 4483
# get safe window from patient 4486
# get safe window from patient 4492
# get safe window from patient 4493
# get safe window from patient 4494
# get safe window from patient 4496
# get safe window from patient 4502
# get safe window from patient 4504
# get safe window from patient 4507
# get safe window from patient 4508
# get safe window from patient 4517
# get safe window from patient 4518
# get safe window from patient 4520
# get safe window from patient 4524
# get safe window from patient 4531
# get safe window from patient 4534
# get safe window from patient 4536
# get safe window from patient 4544
# get safe window from patient 4548
# get safe window from patient 4554
# get safe window from patient 4558
# get safe window from patient 4559
# get safe window from patient 4560
# get safe window from patient 4574
# get safe window from patient 4585
# get safe window from patient 4588
# get safe window from patient 4593
# get safe window from patient 4595
# get safe window from patient 4597
# get safe window from patient 4599
# get safe window from patient 4601
# get safe window from patient 4610
# get safe window from patient 4612
# get safe window from patient 4615
# get safe window from patient 4616
# get safe window from patient 4618
# get safe window from patient 4622
# get safe window from patient 4626
# get safe window from patient 4628
# get safe window from patient 4632
# get safe window from patient 4638
# get safe window from patient 4640
# get safe window from patient 4641
# get safe window from patient 4642
# get safe window from patient 4643
# get safe window from patient 4645
# get safe window from patient 4652
# get safe window from patient 4656
# get safe window from patient 4659
# get safe window from patient 4661
# get safe window from patient 4664
# get safe window from patient 4670
# get safe window from patient 4672
# get safe window from patient 4676
# get safe window from patient 4682
# get safe window from patient 4684
# get safe window from patient 4690
# get safe window from patient 4691
# get safe window from patient 4693
# get safe window from patient 4695
# get safe window from patient 4697
# get safe window from patient 4699
# get safe window from patient 4702
# get safe window from patient 4711
# get safe window from patient 4721
# get safe window from patient 4723
# get safe window from patient 4724
# get safe window from patient 4726
# get safe window from patient 4729
# get safe window from patient 4735
# get safe window from patient 4742
# get safe window from patient 4743
# get safe window from patient 4746
# get safe window from patient 4751
# get safe window from patient 4754
# get safe window from patient 4756
# get safe window from patient 4764
# get safe window from patient 4766
# get safe window from patient 4769
# get safe window from patient 4771
# get safe window from patient 4775
# get safe window from patient 4781
# get safe window from patient 4789
# get safe window from patient 4791
# get safe window from patient 4792
# get safe window from patient 4795
# get safe window from patient 4798
# get safe window from patient 4799
# get safe window from patient 4804
# get safe window from patient 4810
# get safe window from patient 4811
# get safe window from patient 4816
# get safe window from patient 4820
# get safe window from patient 4826
# get safe window from patient 4827
# get safe window from patient 4829
# get safe window from patient 4833
# get safe window from patient 4834
# get safe window from patient 4840
# get safe window from patient 4848
# get safe window from patient 4857
# get safe window from patient 4860
# get safe window from patient 4863
# get safe window from patient 4864
# get safe window from patient 4869
# get safe window from patient 4876
# get safe window from patient 4877
# get safe window from patient 4880
# get safe window from patient 4881
# get safe window from patient 4884
# get safe window from patient 4890
# get safe window from patient 4891
# get safe window from patient 4892
# get safe window from patient 4893
# get safe window from patient 4894
# get safe window from patient 4896
# get safe window from patient 4900
# get safe window from patient 4909
# get safe window from patient 4910
# get safe window from patient 4911
# get safe window from patient 4914
# get safe window from patient 4918
# get safe window from patient 4920
# get safe window from patient 4921
# get safe window from patient 4927
# get safe window from patient 4940
# get safe window from patient 4950
# get safe window from patient 4955
# get safe window from patient 4959
# get safe window from patient 4960
# get safe window from patient 4962
# get safe window from patient 4965
# get safe window from patient 4966
# get safe window from patient 4969
# get safe window from patient 4971
# get safe window from patient 4974
# get safe window from patient 4980
# get safe window from patient 4989
# get safe window from patient 4996
# get safe window from patient 5001
# get safe window from patient 5016
# get safe window from patient 5018
# get safe window from patient 5023
# get safe window from patient 5025
# get safe window from patient 5033
# get safe window from patient 5037
# get safe window from patient 5042
# get safe window from patient 5043
# get safe window from patient 5046
# get safe window from patient 5067
# get safe window from patient 5068
# get safe window from patient 5069
# get safe window from patient 5077
# get safe window from patient 5079
# get safe window from patient 5080
# get safe window from patient 5081
# get safe window from patient 5087
# get safe window from patient 5089
# get safe window from patient 5100
# get safe window from patient 5102
# get safe window from patient 5106
# get safe window from patient 5107
# get safe window from patient 5108
# get safe window from patient 5110
# get safe window from patient 5113
# get safe window from patient 5119
# get safe window from patient 5123
# get safe window from patient 5126
# get safe window from patient 5135
# get safe window from patient 5138
# get safe window from patient 5143
# get safe window from patient 5147
# get safe window from patient 5158
# get safe window from patient 5160
# get safe window from patient 5163
# get safe window from patient 5164
# get safe window from patient 5165
# get safe window from patient 5168
# get safe window from patient 5175
# get safe window from patient 5188
# get safe window from patient 5189
# get safe window from patient 5192
# get safe window from patient 5193
# get safe window from patient 5195
# get safe window from patient 5197
# get safe window from patient 5198
# get safe window from patient 5207
# get safe window from patient 5208
# get safe window from patient 5210
# get safe window from patient 5214
# get safe window from patient 5216
# get safe window from patient 5219
# get safe window from patient 5224
# get safe window from patient 5226
# get safe window from patient 5227
# get safe window from patient 5230
# get safe window from patient 5231
# get safe window from patient 5232
# get safe window from patient 5239
# get safe window from patient 5240
# get safe window from patient 5241
# get safe window from patient 5242
# get safe window from patient 5243
# get safe window from patient 8329
# get safe window from patient 8331
# get safe window from patient 8332
# get safe window from patient 8334
# get safe window from patient 8336
# get safe window from patient 8337
# get safe window from patient 8341
# get safe window from patient 8345
# get safe window from patient 8348
# get safe window from patient 8349
# get safe window from patient 8351
# get safe window from patient 8367
# get safe window from patient 8371
# get safe window from patient 8373
# get safe window from patient 8379
# get safe window from patient 8382
# get safe window from patient 8384
# get safe window from patient 8385
# get safe window from patient 8386
# get safe window from patient 8389
# get safe window from patient 8392
# get safe window from patient 8397
# get safe window from patient 8404
# get safe window from patient 8415
# get safe window from patient 8422
# get safe window from patient 8428
# get safe window from patient 8429
# get safe window from patient 8430
# get safe window from patient 8431
# get safe window from patient 8433
# get safe window from patient 8434
# get safe window from patient 8441
# get safe window from patient 8448
# get safe window from patient 8450
# get safe window from patient 8451
# get safe window from patient 8453
# get safe window from patient 8455
# get safe window from patient 8462
# get safe window from patient 8469
# get safe window from patient 8470
# get safe window from patient 8471
# get safe window from patient 8472
# get safe window from patient 8473
# get safe window from patient 8481
# get safe window from patient 8482
# get safe window from patient 8484
# get safe window from patient 8487
# get safe window from patient 8489
# get safe window from patient 8494
# get safe window from patient 8499
# get safe window from patient 8501
# get safe window from patient 8502
# get safe window from patient 8505
# get safe window from patient 8509
# get safe window from patient 8512
# get safe window from patient 8513
# get safe window from patient 8522
# get safe window from patient 8528
# get safe window from patient 8530
# get safe window from patient 8531
# get safe window from patient 8540
# get safe window from patient 8541
# get safe window from patient 8542
# get safe window from patient 8544
# get safe window from patient 8545
# get safe window from patient 8552
# get safe window from patient 8563
# get safe window from patient 8564
# get safe window from patient 8567
# get safe window from patient 8568
# get safe window from patient 8574
# get safe window from patient 8592
# get safe window from patient 8596
# get safe window from patient 8602
# get safe window from patient 8610
# get safe window from patient 8614
# get safe window from patient 8619
# get safe window from patient 8625
# get safe window from patient 8632
# get safe window from patient 8634
# get safe window from patient 8636
# get safe window from patient 8637
# get safe window from patient 8643
# get safe window from patient 8646
# get safe window from patient 8654
# get safe window from patient 8655
# get safe window from patient 8660
# get safe window from patient 8662
# get safe window from patient 8665
# get safe window from patient 8667
# get safe window from patient 8670
# get safe window from patient 8681
# get safe window from patient 8683
# get safe window from patient 8699
# get safe window from patient 8701
# get safe window from patient 8711
# get safe window from patient 8715
# get safe window from patient 8730
# get safe window from patient 8731
# get safe window from patient 8737
# get safe window from patient 8740
# get safe window from patient 8744
# get safe window from patient 8747
# get safe window from patient 8751
# get safe window from patient 8753
# get safe window from patient 8754
# get safe window from patient 8761
# get safe window from patient 8769
# get safe window from patient 8770
# get safe window from patient 8771
# get safe window from patient 8773
# get safe window from patient 8778
# get safe window from patient 8781
# get safe window from patient 8783
# get safe window from patient 8785
# get safe window from patient 8788
# get safe window from patient 8791
# get safe window from patient 8795
# get safe window from patient 8798
# get safe window from patient 8806
# get safe window from patient 8809
# get safe window from patient 8810
# get safe window from patient 8811
# get safe window from patient 8812
# get safe window from patient 8822
# get safe window from patient 8825
# get safe window from patient 8835
# get safe window from patient 8836
# get safe window from patient 8837
# get safe window from patient 8838
# get safe window from patient 8847
# get safe window from patient 8850
# get safe window from patient 8852
# get safe window from patient 8859
# get safe window from patient 8869
# get safe window from patient 8870
# get safe window from patient 8875
# get safe window from patient 8876
# get safe window from patient 8877
# get safe window from patient 8880
# get safe window from patient 8885
# get safe window from patient 8886
# get safe window from patient 8894
# get safe window from patient 8898
# get safe window from patient 8900
# get safe window from patient 8901
# get safe window from patient 8902
# get safe window from patient 8903
# get safe window from patient 8912
# get safe window from patient 8916
# get safe window from patient 8924
# get safe window from patient 8932
# get safe window from patient 8934
# get safe window from patient 8948
# get safe window from patient 8949
# get safe window from patient 8952
# get safe window from patient 8957
# get safe window from patient 8963
# get safe window from patient 8967
# get safe window from patient 8970
# get safe window from patient 8974
# get safe window from patient 8979
# get safe window from patient 8983
# get safe window from patient 8984
# get safe window from patient 8998
# get safe window from patient 9001
# get safe window from patient 9016
# get safe window from patient 9018
# get safe window from patient 9031
# get safe window from patient 9033
# get safe window from patient 9037
# get safe window from patient 9047
# get safe window from patient 9051
# get safe window from patient 9055
# get safe window from patient 9059
# get safe window from patient 9062
# get safe window from patient 9068
# get safe window from patient 9080
# get safe window from patient 9083
# get safe window from patient 9085
# get safe window from patient 9089
# get safe window from patient 9091
# get safe window from patient 9095
# get safe window from patient 9101
# get safe window from patient 9111
# get safe window from patient 9115
# get safe window from patient 9124
# get safe window from patient 9126
# get safe window from patient 9129
# get safe window from patient 9130
# get safe window from patient 9134
# get safe window from patient 9139
# get safe window from patient 9145
# get safe window from patient 9146
# get safe window from patient 9152
# get safe window from patient 9156
# get safe window from patient 9159
# get safe window from patient 9162
# get safe window from patient 9167
# get safe window from patient 9168
# get safe window from patient 9172
# get safe window from patient 9178
# get safe window from patient 9182
# get safe window from patient 9185
# get safe window from patient 9190
# get safe window from patient 9201
# get safe window from patient 9205
# get safe window from patient 9206
# get safe window from patient 9209
# get safe window from patient 9210
# get safe window from patient 9218
# get safe window from patient 9229
# get safe window from patient 9245
# get safe window from patient 9251
# get safe window from patient 9252
# get safe window from patient 9257
# get safe window from patient 9259
# get safe window from patient 9262
# get safe window from patient 9263
# get safe window from patient 9270
# get safe window from patient 9271
# get safe window from patient 9272
# get safe window from patient 9275
# get safe window from patient 9280
# get safe window from patient 9281
# get safe window from patient 9284
# get safe window from patient 9296
# get safe window from patient 9298
# get safe window from patient 9300
# get safe window from patient 9302
# get safe window from patient 9303
# get safe window from patient 9311
# get safe window from patient 9312
# get safe window from patient 9313
# get safe window from patient 9317
# get safe window from patient 9326
# get safe window from patient 9332
# get safe window from patient 9337
# get safe window from patient 9338
# get safe window from patient 9342
# get safe window from patient 9344
# get safe window from patient 9350
# get safe window from patient 9355
# get safe window from patient 9359
# get safe window from patient 9361
# get safe window from patient 9363
# get safe window from patient 9366
# get safe window from patient 9368
# get safe window from patient 9371
# get safe window from patient 9374
# get safe window from patient 9382
# get safe window from patient 9385
# get safe window from patient 9391
# get safe window from patient 9394
# get safe window from patient 9395
# get safe window from patient 9398
# get safe window from patient 9400
# get safe window from patient 9409
# get safe window from patient 9417
# get safe window from patient 9423
# get safe window from patient 9427
# get safe window from patient 9429
# get safe window from patient 9432
# get safe window from patient 9441
# get safe window from patient 9442
# get safe window from patient 9445
# get safe window from patient 9446
# get safe window from patient 9448
# get safe window from patient 9453
# get safe window from patient 9454
# get safe window from patient 9461
# get safe window from patient 9463
# get safe window from patient 9464
# get safe window from patient 9465
# get safe window from patient 9466
# get safe window from patient 9474
# get safe window from patient 9481
# get safe window from patient 9487
# get safe window from patient 9491
# get safe window from patient 9498
# get safe window from patient 9503
# get safe window from patient 9504
# get safe window from patient 9509
# get safe window from patient 9518
# get safe window from patient 9528
# get safe window from patient 9530
# get safe window from patient 9538
# get safe window from patient 9540
# get safe window from patient 9541
# get safe window from patient 9550
# get safe window from patient 9557
# get safe window from patient 9558
# get safe window from patient 9560
# get safe window from patient 9569
# get safe window from patient 9577
# get safe window from patient 9578
# get safe window from patient 9582
# get safe window from patient 9583
# get safe window from patient 9584
# get safe window from patient 9588
# get safe window from patient 9589
# get safe window from patient 9590
# get safe window from patient 9591
# get safe window from patient 9598
# get safe window from patient 9599
# get safe window from patient 9607
# get safe window from patient 9610
# get safe window from patient 9611
# get safe window from patient 9612
# get safe window from patient 9619
# get safe window from patient 9622
# get safe window from patient 9627
# get safe window from patient 9632
# get safe window from patient 9634
# get safe window from patient 9635
# get safe window from patient 9637
# get safe window from patient 9646
# get safe window from patient 9647
# get safe window from patient 9648
# get safe window from patient 9653
# get safe window from patient 9657
# get safe window from patient 9660
# get safe window from patient 9664
# get safe window from patient 9666
# get safe window from patient 9668
# get safe window from patient 9669
# get safe window from patient 9671
# get safe window from patient 9672
# get safe window from patient 9686
# get safe window from patient 9688
# get safe window from patient 9690
# get safe window from patient 9692
# get safe window from patient 9693
# get safe window from patient 9694
# get safe window from patient 9695
# get safe window from patient 9697
# get safe window from patient 9700
# get safe window from patient 9702
# get safe window from patient 9708
# get safe window from patient 9713
# get safe window from patient 9714
# get safe window from patient 9724
# get safe window from patient 9726
# get safe window from patient 9734
# get safe window from patient 9739
# get safe window from patient 9744
# get safe window from patient 9745
# get safe window from patient 9764
# get safe window from patient 9767
# get safe window from patient 9771
# get safe window from patient 9773
# get safe window from patient 9784
# get safe window from patient 9791
# get safe window from patient 9794
# get safe window from patient 9800
# get safe window from patient 9807
# get safe window from patient 9811
# get safe window from patient 9812
# get safe window from patient 9816
# get safe window from patient 9821
# get safe window from patient 9827
# get safe window from patient 9828
# get safe window from patient 9832
# get safe window from patient 9834
# get safe window from patient 9838
# get safe window from patient 9841
# get safe window from patient 9844
# get safe window from patient 9850
# get safe window from patient 9853
# get safe window from patient 9865
# get safe window from patient 9869
# get safe window from patient 9877
# get safe window from patient 9878
# get safe window from patient 9879
# get safe window from patient 9880
# get safe window from patient 9882
# get safe window from patient 9883
# get safe window from patient 9887
# get safe window from patient 9890
# get safe window from patient 9902
# get safe window from patient 9903
# get safe window from patient 9908
# get safe window from patient 9916
# get safe window from patient 9920
# get safe window from patient 9924
# get safe window from patient 9933
# get safe window from patient 9937
# get safe window from patient 9939
# get safe window from patient 9941
# get safe window from patient 9946
# get safe window from patient 9953

# %%
safe_df.to_csv('../data/safe48_uva.csv', index = False)
